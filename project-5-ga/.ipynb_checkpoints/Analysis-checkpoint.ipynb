# %%
import matplotlib.pyplot as plt
import pandas as pd

#EXPERIMENT 1
#This is the plot for the Fitness Evaluation Vs Best fintess for each generation for the Random Mutation Hill Climber 
#for upto 2000 runs to find the optimal. 
plt.figure(figsize=(5,10))
ax = plt.subplot()
plt.xlabel("Fitness Evaluation for Generation"); plt.ylabel("Best Fitness for Generation")
for i in range(1, 31):
    df = pd.read_csv("HillClimber" + str(i), delimiter = ",", skiprows = [0])
    x = df["FitnessEval"]
    y = df["BestFitness"]
    ax.plot(x, y)

# %%
#EXPERIMENT 2
#This is the plot for the Fitness Evaluation Vs Best fintess for each generation for the Genetic Algorithm Royal Roads 
#function with no intermediate levels for upto 2000 runs to find the optimal. 

plt.figure(figsize=(5,10))
ax = plt.subplot()
plt.xlabel("Fitness Evaluation for Generation"); plt.ylabel("Best Fitness for Generation")
for i in range(1, 22):
    df = pd.read_csv("GARR" + str(i), delimiter = ",", skiprows = [0])
    x = df["FitnessEval"]
    y = df["BestFitness"]
    ax.plot(x, y)

# %%
#EXPERIMENT 3

#This is the plot for the Fitness Evaluation Vs Best fintess for each generation for the Genetic Algorithm Royal Roads 
#function with no intermediate levels for upto 2000 runs to find the optimal. 

plt.figure(figsize=(5, 10))
ax = plt.subplot()
plt.xlabel("Fitness Evaluation for Generation"); plt.ylabel("Best Fitness for Generation")
for i in range(1, 31):
    df = pd.read_csv("GARRIntermediate" + str(i), delimiter = ",", skiprows = [0])
    x = df["FitnessEval"]
    y = df["BestFitness"]
    ax.plot(x, y)

# %%
#This is the plot for the max Fitness Evaluation and corresponding fitness for each run for each experriment. 

plt.figure(figsize=(5, 10))
# ax = plt.subplot()
plt.xlabel("Fitness Evaluation for Generation"); plt.ylabel("Best Fitness for Generation")
for i in range(1, 31):
    df1 = pd.read_csv("HillClimber" + str(i), delimiter = ",", skiprows = [0])
    df2 = pd.read_csv("GARR" + str(i), delimiter = ",", skiprows = [0])
    df3 = pd.read_csv("GARRIntermediate" + str(i), delimiter = ",", skiprows = [0])
    x1 = df1["FitnessEval"].max()
    index_for_max = df1["FitnessEval"].idxmax()
    y1 = df1.iloc[index_for_max, 1]
    plt.scatter(x1, y1, color = 'red')
    x2 = df2["FitnessEval"].max()
    y2 = df2.iloc[df2["FitnessEval"].idxmax(), 1]
    plt.scatter(x2, y2, color = 'blue')
    x3 = df3["FitnessEval"].max()
    y3 = df3.iloc[df3["FitnessEval"].idxmax(), 1]
    plt.scatter(x3, y3, color = 'green')

# %%
#This is the plot for the max Fitness Evaluation and corresponding fitness for each run for each experriment. 

plt.figure(figsize=(5, 10))
# ax = plt.subplot()
plt.xlabel("Fitness Evaluation for Generation"); plt.ylabel("Best Fitness for Generation")
for i in range(1, 31):
    df1 = pd.read_csv("HillClimber" + str(i), delimiter = ",", skiprows = [0])
    df2 = pd.read_csv("GARR" + str(i), delimiter = ",", skiprows = [0])
    df3 = pd.read_csv("GARRIntermediate" + str(i), delimiter = ",", skiprows = [0])
    x1 = df1["FitnessEval"].min()
    index_for_min = df1["FitnessEval"].idxmin()
    y1 = df1.iloc[index_for_min, 1]
    plt.scatter(x1, y1, color = 'red')
    x2 = df2["FitnessEval"].min()
    y2 = df2.iloc[df2["FitnessEval"].idxmin(), 1]
    plt.scatter(x2, y2, color = 'blue')
    x3 = df3["FitnessEval"].min()
    y3 = df3.iloc[df3["FitnessEval"].idxmin(), 1]
    plt.scatter(x3, y3, color = 'green')
